# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime
from math import sqrt
from keras.models import Sequential
from keras.layers import Dense, Dropout,LSTM
from keras.models import load_model
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.metrics import accuracy_score,confusion_matrix
import seaborn as sns
import matplotlib as mpl
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
mpl.rcParams['font.family'] = 'Times New Roman'

# %%
path = 'Data/Phosphate.xlsx'
df001 = pd.read_excel(path, sheet_name='R1', header=0, index_col=0); print("READING df001 Done")
df002 = pd.read_excel(path, sheet_name='R2', header=0, index_col=0); print("READING df002 Done")
df003 = pd.read_excel(path, sheet_name='R3', header=0, index_col=0); print("READING df003 Done")
df004 = pd.read_excel(path, sheet_name='R4', header=0, index_col=0); print("READING df004 Done")
df005 = pd.read_excel(path, sheet_name='R5', header=0, index_col=0); print("READING df005 Done")
df006 = pd.read_excel(path, sheet_name='R6', header=0, index_col=0); print("READING df006 Done")
df007 = pd.read_excel(path, sheet_name='R7', header=0, index_col=0); print("READING df007 Done")
df008 = pd.read_excel(path, sheet_name='R8', header=0, index_col=0); print("READING df008 Done")
df009 = pd.read_excel(path, sheet_name='R9', header=0, index_col=0); print("READING df009 Done")
df010 = pd.read_excel(path, sheet_name='R10', header=0, index_col=0); print("READING df010 Done")
df011 = pd.read_excel(path, sheet_name='R11', header=0, index_col=0); print("READING df011 Done")
df012 = pd.read_excel(path, sheet_name='R12', header=0, index_col=0); print("READING df012 Done")
df013 = pd.read_excel(path, sheet_name='R13', header=0, index_col=0); print("READING df013 Done")
df014 = pd.read_excel(path, sheet_name='R14', header=0, index_col=0); print("READING df014 Done")
df015 = pd.read_excel(path, sheet_name='R15', header=0, index_col=0); print("READING df015 Done")
df016 = pd.read_excel(path, sheet_name='R16', header=0, index_col=0); print("READING df016 Done")
df017 = pd.read_excel(path, sheet_name='R17', header=0, index_col=0); print("READING df017 Done")
df018 = pd.read_excel(path, sheet_name='R18', header=0, index_col=0); print("READING df018 Done")
df019 = pd.read_excel(path, sheet_name='R19', header=0, index_col=0); print("READING df019 Done")
df020 = pd.read_excel(path, sheet_name='R20', header=0, index_col=0); print("READING df020 Done")
df021 = pd.read_excel(path, sheet_name='R21', header=0, index_col=0); print("READING df021 Done")
df022 = pd.read_excel(path, sheet_name='R22', header=0, index_col=0); print("READING df022 Done")
df023 = pd.read_excel(path, sheet_name='R23', header=0, index_col=0); print("READING df023 Done")
df024 = pd.read_excel(path, sheet_name='R24', header=0, index_col=0); print("READING df024 Done")
# Out:
# READING df001 Done
# READING df002 Done
# READING df003 Done
# READING df004 Done
# READING df005 Done
# READING df006 Done
# READING df007 Done
# READING df008 Done
# READING df009 Done
# READING df010 Done
# READING df011 Done
# READING df012 Done
# READING df013 Done
# READING df014 Done
# READING df015 Done
# READING df016 Done
# READING df017 Done
# READING df018 Done
# READING df019 Done
# READING df020 Done
# READING df021 Done
# READING df022 Done
# READING df023 Done
# READING df024 Done

# %%
print('01', df001[df001['Cnn'] < 0])
print('02', df002[df002['Cnn'] < 0])
print('03', df003[df003['Cnn'] < 0])
print('04', df004[df004['Cnn'] < 0])
print('05', df005[df005['Cnn'] < 0])
print('06', df006[df006['Cnn'] < 0])
print('07', df007[df007['Cnn'] < 0])
print('08', df008[df008['Cnn'] < 0])
print('09', df009[df009['Cnn'] < 0])
print('10', df010[df010['Cnn'] < 0])
print('11', df011[df011['Cnn'] < 0])
print('12', df012[df012['Cnn'] < 0])
print('13', df013[df013['Cnn'] < 0])
print('14', df014[df014['Cnn'] < 0])
print('15', df015[df015['Cnn'] < 0])
print('16', df016[df016['Cnn'] < 0])
print('17', df017[df017['Cnn'] < 0])
print('18', df018[df018['Cnn'] < 0])
print('19', df019[df019['Cnn'] < 0])
print('20', df020[df020['Cnn'] < 0])
print('21', df021[df021['Cnn'] < 0])
print('22', df022[df022['Cnn'] < 0])
print('23', df023[df023['Cnn'] < 0])
print('24', df024[df024['Cnn'] < 0])
# Out:
# 01 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 02 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 03 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 04 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 05 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 06 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 07 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 08 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 09 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 10 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# Index: []
# 11 Empty DataFrame
# Columns: [STT, Year, Month, Day, Hour, Qt, Ct, Qs, Cnn]
# ...

# %%
column_df = ['Day', 'Month', 'Year', 'Ltn', 'Cnn', 'Qs', 'Cqc', 'Qt', 'Ct', 'Lt']
dfngay001, dfkhoRWEC001, dfmuaRWEC001 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay002, dfkhoRWEC002, dfmuaRWEC002 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay003, dfkhoRWEC003, dfmuaRWEC003 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay004, dfkhoRWEC004, dfmuaRWEC004 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay005, dfkhoRWEC005, dfmuaRWEC005 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay006, dfkhoRWEC006, dfmuaRWEC006 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay007, dfkhoRWEC007, dfmuaRWEC007 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay008, dfkhoRWEC008, dfmuaRWEC008 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay009, dfkhoRWEC009, dfmuaRWEC009 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay010, dfkhoRWEC010, dfmuaRWEC010 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay011, dfkhoRWEC011, dfmuaRWEC011 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay012, dfkhoRWEC012, dfmuaRWEC012 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay013, dfkhoRWEC013, dfmuaRWEC013 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay014, dfkhoRWEC014, dfmuaRWEC014 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay015, dfkhoRWEC015, dfmuaRWEC015 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay016, dfkhoRWEC016, dfmuaRWEC016 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay017, dfkhoRWEC017, dfmuaRWEC017 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay018, dfkhoRWEC018, dfmuaRWEC018 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay019, dfkhoRWEC019, dfmuaRWEC019 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay020, dfkhoRWEC020, dfmuaRWEC020 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay021, dfkhoRWEC021, dfmuaRWEC021 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay022, dfkhoRWEC022, dfmuaRWEC022 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay023, dfkhoRWEC023, dfmuaRWEC023 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)
dfngay024, dfkhoRWEC024, dfmuaRWEC024 = pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df), pd.DataFrame(columns = column_df)

def RWECDay(df):
    dfngay = pd.DataFrame(columns = column_df); index = 0
    for i in range(365):
        start_idx = i * 24; end_idx = (i + 1) * 24
        daily_data = df.iloc[start_idx:end_idx]
        avg_Cqc = 0.1; avg_Lt = 0; avg_Fs = 0.3
        avg_Cnn = daily_data['Cnn'].mean()
        avg_Qs = daily_data['Qs'].mean()
        avg_Qt = daily_data['Qt'].mean()
        avg_Ct = daily_data['Ct'].mean()
        RWEC = 86.4 * (avg_Cqc*avg_Qs - avg_Cnn*avg_Qs - avg_Qt*avg_Ct)*avg_Fs
        value = [daily_data['Day'].iloc[0], daily_data['Month'].iloc[0],
                 daily_data['Year'].iloc[0], RWEC, avg_Cnn, avg_Qs,
                 avg_Cqc, avg_Qt, avg_Ct, avg_Lt]
        dfngay.loc[index] = value; index += 1

    dfngay['datetime'] = pd.to_datetime(dfngay[['Year', 'Month', 'Day']])
    dfkhoseason = dfngay[(dfngay['datetime'].dt.month >= 12) | (dfngay['datetime'].dt.month <= 4)]
    dfkhoseason = dfkhoseason[~((dfkhoseason['datetime'].dt.month == 4) & (dfkhoseason['datetime'].dt.day > 15))]
    dfkhoseason = dfkhoseason.drop(columns=['datetime'])
    dfuotseason = dfngay[(dfngay['datetime'].dt.month < 12) & (dfngay['datetime'].dt.month > 4)]
    dfuotseason = dfuotseason[~((dfuotseason['datetime'].dt.month == 5) & (dfuotseason['datetime'].dt.day <= 15))]
    dfuotseason = dfuotseason.drop(columns=['datetime'])
    return dfngay, dfkhoseason, dfuotseason

dfngay001, dfkhoRWEC001, dfmuaRWEC001 = RWECDay(df001); print("Done Calculating df001")
dfngay002, dfkhoRWEC002, dfmuaRWEC002 = RWECDay(df002); print("Done Calculating df002")
dfngay003, dfkhoRWEC003, dfmuaRWEC003 = RWECDay(df003); print("Done Calculating df003")
dfngay004, dfkhoRWEC004, dfmuaRWEC004 = RWECDay(df004); print("Done Calculating df004")
dfngay005, dfkhoRWEC005, dfmuaRWEC005 = RWECDay(df005); print("Done Calculating df005")
dfngay006, dfkhoRWEC006, dfmuaRWEC006 = RWECDay(df006); print("Done Calculating df006")
dfngay007, dfkhoRWEC007, dfmuaRWEC007 = RWECDay(df007); print("Done Calculating df007")
dfngay008, dfkhoRWEC008, dfmuaRWEC008 = RWECDay(df008); print("Done Calculating df008")
dfngay009, dfkhoRWEC009, dfmuaRWEC009 = RWECDay(df009); print("Done Calculating df009")
dfngay010, dfkhoRWEC010, dfmuaRWEC010 = RWECDay(df010); print("Done Calculating df010")
dfngay011, dfkhoRWEC011, dfmuaRWEC011 = RWECDay(df011); print("Done Calculating df011")
dfngay012, dfkhoRWEC012, dfmuaRWEC012 = RWECDay(df012); print("Done Calculating df012")
dfngay013, dfkhoRWEC013, dfmuaRWEC013 = RWECDay(df013); print("Done Calculating df013")
dfngay014, dfkhoRWEC014, dfmuaRWEC014 = RWECDay(df014); print("Done Calculating df014")
dfngay015, dfkhoRWEC015, dfmuaRWEC015 = RWECDay(df015); print("Done Calculating df015")
dfngay016, dfkhoRWEC016, dfmuaRWEC016 = RWECDay(df016); print("Done Calculating df016")
dfngay017, dfkhoRWEC017, dfmuaRWEC017 = RWECDay(df017); print("Done Calculating df017")
dfngay018, dfkhoRWEC018, dfmuaRWEC018 = RWECDay(df018); print("Done Calculating df018")
dfngay019, dfkhoRWEC019, dfmuaRWEC019 = RWECDay(df019); print("Done Calculating df019")
dfngay020, dfkhoRWEC020, dfmuaRWEC020 = RWECDay(df020); print("Done Calculating df020")
dfngay021, dfkhoRWEC021, dfmuaRWEC021 = RWECDay(df021); print("Done Calculating df021")
dfngay022, dfkhoRWEC022, dfmuaRWEC022 = RWECDay(df022); print("Done Calculating df022")
dfngay023, dfkhoRWEC023, dfmuaRWEC023 = RWECDay(df023); print("Done Calculating df023")
dfngay024, dfkhoRWEC024, dfmuaRWEC024 = RWECDay(df024); print("Done Calculating df024")
# Out:
# Done Calculating df001
# Done Calculating df002
# Done Calculating df003
# Done Calculating df004
# Done Calculating df005
# Done Calculating df006
# Done Calculating df007
# Done Calculating df008
# Done Calculating df009
# Done Calculating df010
# Done Calculating df011
# Done Calculating df012
# Done Calculating df013
# Done Calculating df014
# Done Calculating df015
# Done Calculating df016
# Done Calculating df017
# Done Calculating df018
# Done Calculating df019
# Done Calculating df020
# Done Calculating df021
# Done Calculating df022
# Done Calculating df023
# Done Calculating df024

# %%
data = []
dataframes = {
    'Reach1': pd.DataFrame(dfngay001),
    'Reach2': pd.DataFrame(dfngay002),
    'Reach3': pd.DataFrame(dfngay003),
    'Reach4': pd.DataFrame(dfngay004),
    'Reach5': pd.DataFrame(dfngay005),
    'Reach6': pd.DataFrame(dfngay006),
    'Reach7': pd.DataFrame(dfngay007),
    'Reach8': pd.DataFrame(dfngay008),
    'Reach9': pd.DataFrame(dfngay009),
    'Reach10': pd.DataFrame(dfngay010),
    'Reach11': pd.DataFrame(dfngay011),
    'Reach12': pd.DataFrame(dfngay012),
    'Reach13': pd.DataFrame(dfngay013),
    'Reach14': pd.DataFrame(dfngay014),
    'Reach15': pd.DataFrame(dfngay015),
    'Reach16': pd.DataFrame(dfngay016),
    'Reach17': pd.DataFrame(dfngay017),
    'Reach18': pd.DataFrame(dfngay018),
    'Reach19': pd.DataFrame(dfngay019),
    'Reach20': pd.DataFrame(dfngay020),
    'Reach21': pd.DataFrame(dfngay021),
    'Reach22': pd.DataFrame(dfngay022),
    'Reach23': pd.DataFrame(dfngay023),
    'Reach24': pd.DataFrame(dfngay024),
}
meteorological_factors = ['Qt', 'Ct', 'Qs', 'Cnn']
for station, df in dataframes.items():
    for factor in meteorological_factors:
        pearson_corr = df[factor].corr(df['Ltn'])
        data.append([station, factor, pearson_corr])

# Create a DataFrame from the results
result_df = pd.DataFrame(data, columns=['station', 'met_factor', 'Pearson_R'])
station_order = ['Reach1', 'Reach2', 'Reach3', 'Reach4', 'Reach5', 'Reach6', 'Reach7', 'Reach8', 'Reach9', 'Reach10', 'Reach11',
                  'Reach12', 'Reach13', 'Reach14', 'Reach15', 'Reach16', 'Reach17', 'Reach18', 'Reach19', 'Reach20',
                  'Reach21', 'Reach22', 'Reach23', 'Reach24']
print(result_df)
correlations = result_df.pivot_table(index="station", columns="met_factor", values="Pearson_R")
correlations = correlations.reindex(station_order, axis=0).reindex(meteorological_factors, axis=1)

# Plot heatmap
plt.rcParams['figure.figsize'] = (15, 10)  # Increase figure size
fig = plt.figure()
ax = sns.heatmap(correlations, annot=True, annot_kws={"size": 10}, linewidths=0.01, linecolor="white", cmap="YlOrRd", fmt=".2f")
ax.set_ylabel('Reaches', fontsize=12)
ax.set_xlabel('Concentration, RWEC, river discharge, wastewater discharge (Phosphate 100%)', fontsize=12)

plt.suptitle("Pearson’s coefficient between RWEC, concentration, river discharge \n and wastewater rate (Phosphate 100%)", weight="bold", fontsize=13)

plt.show()

# Save the figure with high resolution
fig.savefig('Output/Phosphate/Pearson_coefficients_Phosphate_100.jpg', format='jpg', dpi=1000)
# Out:
#     station met_factor     Pearson_R
# 0    Reach1         Qt           NaN
# 1    Reach1         Ct           NaN
# 2    Reach1         Qs  3.336823e-01
# 3    Reach1        Cnn -4.859783e-01
# 4    Reach2         Qt -6.628748e-17
# ..      ...        ...           ...
# 91  Reach23        Cnn  4.696058e-01
# 92  Reach24         Qt  1.723084e-16
# 93  Reach24         Ct -1.723084e-16
# 94  Reach24         Qs  1.168280e-01
# 95  Reach24        Cnn  3.886320e-01
#
# [96 rows x 3 columns]
# C:\Users\phamq\AppData\Roaming\Python\Python39\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\phamq\AppData\Roaming\Python\Python39\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
import pandas as pd
from docx import Document

def calculate_averages_and_extremes(df):
    avg_ltn = df['Ltn'].mean()
    avg_cnn = df['Cnn'].mean()
    min_ltn = df['Ltn'].min()
    min_cnn = df['Cnn'].min()
    max_ltn = df['Ltn'].max()
    max_cnn = df['Cnn'].max()

    return avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn

def write_statistics(doc, prefix, avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn):
    doc.add_paragraph(f"{prefix} Trung bình Sức tải: {avg_ltn}")
    doc.add_paragraph(f"{prefix} Trung bình Nồng độ: {avg_cnn}")
    doc.add_paragraph(f"{prefix} Nhỏ nhất Sức tải: {min_ltn}")
    doc.add_paragraph(f"{prefix} Nhỏ nhất Nồng độ: {min_cnn}")
    doc.add_paragraph(f"{prefix} Lớn nhất Sức tải: {max_ltn}")
    doc.add_paragraph(f"{prefix} Lớn nhất Nồng độ: {max_cnn}")
    doc.add_paragraph('-'*75)
# Create a new Document
doc = Document()

# List chứa tất cả các DataFrame
df_list = [dfkhoRWEC001, dfkhoRWEC002, dfkhoRWEC003, dfkhoRWEC004, dfkhoRWEC005, dfkhoRWEC006, dfkhoRWEC007, dfkhoRWEC008, dfkhoRWEC009, dfkhoRWEC010,
           dfkhoRWEC011, dfkhoRWEC012, dfkhoRWEC013, dfkhoRWEC014, dfkhoRWEC015, dfkhoRWEC016, dfkhoRWEC017, dfkhoRWEC018, dfkhoRWEC019, dfkhoRWEC020,
           dfkhoRWEC021, dfkhoRWEC022, dfkhoRWEC023, dfkhoRWEC024]

for i, df in enumerate(df_list, start=1):
    avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn = calculate_averages_and_extremes(df)
    write_statistics(doc, f"Số liệu từ dfdry{i}:", avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn)

# Tính giá trị min và max chung
min_ltn_values = [df['Ltn'].min() for df in df_list]
min_cnn_values = [df['Cnn'].min() for df in df_list]
max_ltn_values = [df['Ltn'].max() for df in df_list]
max_cnn_values = [df['Cnn'].max() for df in df_list]
average_ltn_values = [df['Ltn'].mean() for df in df_list]
average_cnn_values = [df['Cnn'].mean() for df in df_list]

averages_df = pd.DataFrame({
    'Average_Ltn': average_ltn_values,
    'Average_Cnn': average_cnn_values
})

overall_min_ltn = min(min_ltn_values)
overall_min_cnn = min(min_cnn_values)
overall_max_ltn = max(max_ltn_values)
overall_max_cnn = max(max_cnn_values)
overall_average_ltn = averages_df['Average_Ltn'].mean()
overall_average_cnn = averages_df['Average_Cnn'].mean()

df = pd.DataFrame(columns=[f"R{i}" for i in range(1, 25, 1)] + ["Overall"])
df.loc['Average_RWEC'] = np.append(average_ltn_values, overall_average_ltn)
df.loc['Average_Concentration'] = np.append(average_cnn_values, overall_average_cnn)
df.loc['Min_RWEC'] = np.append(min_ltn_values, overall_min_ltn)
df.loc['Min_Concentration'] = np.append(min_cnn_values, overall_min_cnn)
df.loc['Max_RWEC'] = np.append(max_ltn_values, overall_max_ltn)
df.loc['Max_Concentration'] = np.append(max_cnn_values, overall_max_cnn)
df.to_excel('Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của các reach mùa khô.xlsx')

# Write overall statistics to the document
doc.add_paragraph(f"Overall Min của Sức tải mùa khô: {overall_min_ltn}")
doc.add_paragraph(f"Overall Min của Nồng độ mùa khô: {overall_min_cnn}")
doc.add_paragraph(f"Overall Max của Sức tải mùa khô: {overall_max_ltn}")
doc.add_paragraph(f"Overall Max của Nồng độ mùa khô: {overall_max_cnn}")
doc.add_paragraph(f"Overall Trung bình của Sức tải mùa khô: {overall_average_ltn}")
doc.add_paragraph(f"Overall Trung bình của Nồng độ mùa khô: {overall_average_cnn}")

# Save the document
doc.save('Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của các reach mùa khô.docx')

# %%
import pandas as pd
from docx import Document

def calculate_averages_and_extremes(df):
    avg_ltn = df['Ltn'].mean()
    avg_cnn = df['Cnn'].mean()
    min_ltn = df['Ltn'].min()
    min_cnn = df['Cnn'].min()
    max_ltn = df['Ltn'].max()
    max_cnn = df['Cnn'].max()

    return avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn

def write_statistics(doc, prefix, avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn):
    doc.add_paragraph(f"{prefix} Trung bình Sức tải: {avg_ltn}")
    doc.add_paragraph(f"{prefix} Trung bình Nồng độ: {avg_cnn}")
    doc.add_paragraph(f"{prefix} Nhỏ nhất Sức tải: {min_ltn}")
    doc.add_paragraph(f"{prefix} Nhỏ nhất Nồng độ: {min_cnn}")
    doc.add_paragraph(f"{prefix} Lớn nhất Sức tải: {max_ltn}")
    doc.add_paragraph(f"{prefix} Lớn nhất Nồng độ: {max_cnn}")
    doc.add_paragraph('-'*75)

# Create a new Document
doc = Document()

# List chứa tất cả các DataFrame
df_list = [dfmuaRWEC001, dfmuaRWEC002, dfmuaRWEC003, dfmuaRWEC004, dfmuaRWEC005, dfmuaRWEC006, dfmuaRWEC007, dfmuaRWEC008, dfmuaRWEC009, dfmuaRWEC010,
           dfmuaRWEC011, dfmuaRWEC012, dfmuaRWEC013, dfmuaRWEC014, dfmuaRWEC015, dfmuaRWEC016, dfmuaRWEC017, dfmuaRWEC018, dfmuaRWEC019, dfmuaRWEC020,
           dfmuaRWEC021, dfmuaRWEC022, dfmuaRWEC023, dfmuaRWEC024]

for i, df in enumerate(df_list, start=1):
    avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn = calculate_averages_and_extremes(df)
    write_statistics(doc, f"Số liệu từ dfmua{i}:", avg_ltn, avg_cnn, min_ltn, min_cnn, max_ltn, max_cnn)

# Tính giá trị min và max chung
min_ltn_values = [df['Ltn'].min() for df in df_list]
min_cnn_values = [df['Cnn'].min() for df in df_list]
max_ltn_values = [df['Ltn'].max() for df in df_list]
max_cnn_values = [df['Cnn'].max() for df in df_list]
average_ltn_values = [df['Ltn'].mean() for df in df_list]
average_cnn_values = [df['Cnn'].mean() for df in df_list]

averages_df = pd.DataFrame({
    'Average_Ltn': average_ltn_values,
    'Average_Cnn': average_cnn_values
})

overall_min_ltn = min(min_ltn_values)
overall_min_cnn = min(min_cnn_values)
overall_max_ltn = max(max_ltn_values)
overall_max_cnn = max(max_cnn_values)
overall_average_ltn = averages_df['Average_Ltn'].mean()
overall_average_cnn = averages_df['Average_Cnn'].mean()

df = pd.DataFrame(columns=[f"R{i}" for i in range(1, 25, 1)] + ["Overall"])
df.loc['Average_RWEC'] = np.append(average_ltn_values, overall_average_ltn)
df.loc['Average_Concentration'] = np.append(average_cnn_values, overall_average_cnn)
df.loc['Min_RWEC'] = np.append(min_ltn_values, overall_min_ltn)
df.loc['Min_Concentration'] = np.append(min_cnn_values, overall_min_cnn)
df.loc['Max_RWEC'] = np.append(max_ltn_values, overall_max_ltn)
df.loc['Max_Concentration'] = np.append(max_cnn_values, overall_max_cnn)
df.to_excel('Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của các reach mùa mưa.xlsx')

# Write overall statistics to the document
doc.add_paragraph(f"Overall Min của Sức tải mùa mưa: {overall_min_ltn}")
doc.add_paragraph(f"Overall Min của Nồng độ mùa mưa: {overall_min_cnn}")
doc.add_paragraph(f"Overall Max của Sức tải mùa mưa: {overall_max_ltn}")
doc.add_paragraph(f"Overall Max của Nồng độ mùa mưa: {overall_max_cnn}")
doc.add_paragraph(f"Overall Trung bình của Sức tải mùa mưa: {overall_average_ltn}")
doc.add_paragraph(f"Overall Trung bình của Nồng độ mùa mưa: {overall_average_cnn}")

# Save the document
doc.save('Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của các reach mùa mưa.docx')

# %%
def calculate_min_max(df):
    min_Ltn = df['Ltn'].min()
    max_Ltn = df['Ltn'].max()
    avg_Ltn = df['Ltn'].mean()
    min_Cnn = df['Cnn'].min()
    max_Cnn = df['Cnn'].max()
    avg_Cnn = df['Cnn'].mean()
    return min_Ltn, max_Ltn, avg_Ltn, min_Cnn, max_Cnn, avg_Cnn

doc = Document()
min_Ltn_001, max_Ltn_001, avg_Ltn_001, min_Cnn_001, max_Cnn_001, avg_Cnn_001 = calculate_min_max(dfngay001)
min_Ltn_002, max_Ltn_002, avg_Ltn_002, min_Cnn_002, max_Cnn_002, avg_Cnn_002 = calculate_min_max(dfngay002)
min_Ltn_003, max_Ltn_003, avg_Ltn_003, min_Cnn_003, max_Cnn_003, avg_Cnn_003 = calculate_min_max(dfngay003)
min_Ltn_004, max_Ltn_004, avg_Ltn_004, min_Cnn_004, max_Cnn_004, avg_Cnn_004 = calculate_min_max(dfngay004)
min_Ltn_005, max_Ltn_005, avg_Ltn_005, min_Cnn_005, max_Cnn_005, avg_Cnn_005 = calculate_min_max(dfngay005)
min_Ltn_006, max_Ltn_006, avg_Ltn_006, min_Cnn_006, max_Cnn_006, avg_Cnn_006 = calculate_min_max(dfngay006)
min_Ltn_007, max_Ltn_007, avg_Ltn_007, min_Cnn_007, max_Cnn_007, avg_Cnn_007 = calculate_min_max(dfngay007)
min_Ltn_008, max_Ltn_008, avg_Ltn_008, min_Cnn_008, max_Cnn_008, avg_Cnn_008 = calculate_min_max(dfngay008)
min_Ltn_009, max_Ltn_009, avg_Ltn_009, min_Cnn_009, max_Cnn_009, avg_Cnn_009 = calculate_min_max(dfngay009)
min_Ltn_010, max_Ltn_010, avg_Ltn_010, min_Cnn_010, max_Cnn_010, avg_Cnn_010 = calculate_min_max(dfngay010)
min_Ltn_011, max_Ltn_011, avg_Ltn_011, min_Cnn_011, max_Cnn_011, avg_Cnn_011 = calculate_min_max(dfngay011)
min_Ltn_012, max_Ltn_012, avg_Ltn_012, min_Cnn_012, max_Cnn_012, avg_Cnn_012 = calculate_min_max(dfngay012)
min_Ltn_013, max_Ltn_013, avg_Ltn_013, min_Cnn_013, max_Cnn_013, avg_Cnn_013 = calculate_min_max(dfngay013)
min_Ltn_014, max_Ltn_014, avg_Ltn_014, min_Cnn_014, max_Cnn_014, avg_Cnn_014 = calculate_min_max(dfngay014)
min_Ltn_015, max_Ltn_015, avg_Ltn_015, min_Cnn_015, max_Cnn_015, avg_Cnn_015 = calculate_min_max(dfngay015)
min_Ltn_016, max_Ltn_016, avg_Ltn_016, min_Cnn_016, max_Cnn_016, avg_Cnn_016 = calculate_min_max(dfngay016)
min_Ltn_017, max_Ltn_017, avg_Ltn_017, min_Cnn_017, max_Cnn_017, avg_Cnn_017 = calculate_min_max(dfngay017)
min_Ltn_018, max_Ltn_018, avg_Ltn_018, min_Cnn_018, max_Cnn_018, avg_Cnn_018 = calculate_min_max(dfngay018)
min_Ltn_019, max_Ltn_019, avg_Ltn_019, min_Cnn_019, max_Cnn_019, avg_Cnn_019 = calculate_min_max(dfngay019)
min_Ltn_020, max_Ltn_020, avg_Ltn_020, min_Cnn_020, max_Cnn_020, avg_Cnn_020 = calculate_min_max(dfngay020)
min_Ltn_021, max_Ltn_021, avg_Ltn_021, min_Cnn_021, max_Cnn_021, avg_Cnn_021 = calculate_min_max(dfngay021)
min_Ltn_022, max_Ltn_022, avg_Ltn_022, min_Cnn_022, max_Cnn_022, avg_Cnn_022 = calculate_min_max(dfngay022)
min_Ltn_023, max_Ltn_023, avg_Ltn_023, min_Cnn_023, max_Cnn_023, avg_Cnn_023 = calculate_min_max(dfngay023)
min_Ltn_024, max_Ltn_024, avg_Ltn_024, min_Cnn_024, max_Cnn_024, avg_Cnn_024 = calculate_min_max(dfngay024)

doc.add_paragraph("Min và Max của Ltn và Cnn trong df001:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_001}, Max Ltn: {max_Ltn_001}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_001}, Max Cnn: {max_Cnn_001}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df002:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_002}, Max Ltn: {max_Ltn_002}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_002}, Max Cnn: {max_Cnn_002}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df003:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_003}, Max Ltn: {max_Ltn_003}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_003}, Max Cnn: {max_Cnn_003}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df004:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_004}, Max Ltn: {max_Ltn_004}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_004}, Max Cnn: {max_Cnn_004}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df005:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_005}, Max Ltn: {max_Ltn_005}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_005}, Max Cnn: {max_Cnn_005}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df006:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_006}, Max Ltn: {max_Ltn_006}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_006}, Max Cnn: {max_Cnn_006}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df007:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_007}, Max Ltn: {max_Ltn_007}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_007}, Max Cnn: {max_Cnn_007}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df008:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_008}, Max Ltn: {max_Ltn_008}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_008}, Max Cnn: {max_Cnn_008}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df009:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_009}, Max Ltn: {max_Ltn_009}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_009}, Max Cnn: {max_Cnn_009}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df010:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_010}, Max Ltn: {max_Ltn_010}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_010}, Max Cnn: {max_Cnn_010}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df011:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_011}, Max Ltn: {max_Ltn_011}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_011}, Max Cnn: {max_Cnn_011}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df012:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_012}, Max Ltn: {max_Ltn_012}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_012}, Max Cnn: {max_Cnn_012}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df013:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_013}, Max Ltn: {max_Ltn_013}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_013}, Max Cnn: {max_Cnn_013}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df014:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_014}, Max Ltn: {max_Ltn_014}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_014}, Max Cnn: {max_Cnn_014}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df015:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_015}, Max Ltn: {max_Ltn_015}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_015}, Max Cnn: {max_Cnn_015}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df016:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_016}, Max Ltn: {max_Ltn_016}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_016}, Max Cnn: {max_Cnn_016}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df017:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_017}, Max Ltn: {max_Ltn_017}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_017}, Max Cnn: {max_Cnn_017}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df018:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_018}, Max Ltn: {max_Ltn_018}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_018}, Max Cnn: {max_Cnn_018}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df019:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_019}, Max Ltn: {max_Ltn_019}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_019}, Max Cnn: {max_Cnn_019}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df020:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_020}, Max Ltn: {max_Ltn_020}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_020}, Max Cnn: {max_Cnn_020}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df021:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_021}, Max Ltn: {max_Ltn_021}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_021}, Max Cnn: {max_Cnn_021}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df022:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_022}, Max Ltn: {max_Ltn_022}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_022}, Max Cnn: {max_Cnn_022}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df023:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_023}, Max Ltn: {max_Ltn_023}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_023}, Max Cnn: {max_Cnn_023}")
doc.add_paragraph('-'*75)
doc.add_paragraph("Min và Max của Ltn và Cnn trong df024:")
doc.add_paragraph(f"Min Ltn: {min_Ltn_024}, Max Ltn: {max_Ltn_024}")
doc.add_paragraph(f"Min Cnn: {min_Cnn_024}, Max Cnn: {max_Cnn_024}")
doc.add_paragraph('-'*100)

# Tính min của các giá trị min_Ltn_00x
min_Ltn_values = [min_Ltn_001, min_Ltn_002, min_Ltn_003, min_Ltn_004, min_Ltn_005, min_Ltn_006,
                  min_Ltn_007, min_Ltn_008, min_Ltn_009, min_Ltn_010, min_Ltn_011, min_Ltn_012,
                  min_Ltn_013, min_Ltn_014, min_Ltn_015, min_Ltn_016, min_Ltn_017, min_Ltn_018,
                  min_Ltn_019, min_Ltn_020, min_Ltn_021, min_Ltn_022, min_Ltn_023, min_Ltn_024]
overall_min_Ltn = min(min_Ltn_values)

# Tương tự, bạn cũng có thể tính min của các giá trị min_Cnn_00x
min_Cnn_values = [min_Cnn_001, min_Cnn_002, min_Cnn_003, min_Cnn_004, min_Cnn_005, min_Cnn_006,
                  min_Cnn_007, min_Cnn_008, min_Cnn_009, min_Cnn_010, min_Cnn_011, min_Cnn_012,
                  min_Cnn_013, min_Cnn_014, min_Cnn_015, min_Cnn_016, min_Cnn_017, min_Cnn_018,
                  min_Cnn_019, min_Cnn_020, min_Cnn_021, min_Cnn_022, min_Cnn_023, min_Cnn_024]
overall_min_Cnn = min(min_Cnn_values)

doc.add_paragraph(f"Overall Min của Ltn: {overall_min_Ltn}")
doc.add_paragraph(f"Overall Min của Cnn: {overall_min_Cnn}")

doc.add_paragraph('-'*100)

# Tính max của các giá trị max_Ltn_00x
max_Ltn_values = [max_Ltn_001, max_Ltn_002, max_Ltn_003, max_Ltn_004, max_Ltn_005, max_Ltn_006,
                  max_Ltn_007, max_Ltn_008, max_Ltn_009, max_Ltn_010, max_Ltn_011, max_Ltn_012,
                  max_Ltn_013, max_Ltn_014, max_Ltn_015, max_Ltn_016, max_Ltn_017, max_Ltn_018,
                  max_Ltn_019, max_Ltn_020, max_Ltn_021, max_Ltn_022, max_Ltn_023, max_Ltn_024]
overall_max_Ltn = max(max_Ltn_values)

# Tương tự, bạn cũng có thể tính max của các giá trị max_Cnn_00x
max_Cnn_values = [max_Cnn_001, max_Cnn_002, max_Cnn_003, max_Cnn_004, max_Cnn_005, max_Cnn_006,
                  max_Cnn_007, max_Cnn_008, max_Cnn_009, max_Cnn_010, max_Cnn_011, max_Cnn_012,
                  max_Cnn_013, max_Cnn_014, max_Cnn_015, max_Cnn_016, max_Cnn_017, max_Cnn_018,
                  max_Cnn_019, max_Cnn_020, max_Cnn_021, max_Cnn_022, max_Cnn_023, max_Cnn_024]
overall_max_Cnn = max(max_Cnn_values)

doc.add_paragraph(f"Overall Max của Ltn: {overall_max_Ltn}")
doc.add_paragraph(f"Overall Max của Cnn: {overall_max_Cnn}")

doc.add_paragraph ('-'*100)

avg_Ltn_values = [avg_Ltn_001, avg_Ltn_002, avg_Ltn_003, avg_Ltn_004, avg_Ltn_005, avg_Ltn_006,
                  avg_Ltn_007, avg_Ltn_008, avg_Ltn_009, avg_Ltn_010, avg_Ltn_011, avg_Ltn_012,
                  avg_Ltn_013, avg_Ltn_014, avg_Ltn_015, avg_Ltn_016, avg_Ltn_017, avg_Ltn_018,
                  avg_Ltn_019, avg_Ltn_020, avg_Ltn_021, avg_Ltn_022, avg_Ltn_023, avg_Ltn_024]
overall_avg_Ltn = min(avg_Ltn_values)

avg_Cnn_values = [avg_Cnn_001, avg_Cnn_002, avg_Cnn_003, avg_Cnn_004, avg_Cnn_005, avg_Cnn_006,
                  avg_Cnn_007, avg_Cnn_008, avg_Cnn_009, avg_Cnn_010, avg_Cnn_011, avg_Cnn_012,
                  avg_Cnn_013, avg_Cnn_014, avg_Cnn_015, avg_Cnn_016, avg_Cnn_017, avg_Cnn_018,
                  avg_Cnn_019, avg_Cnn_020, avg_Cnn_021, avg_Cnn_022, avg_Cnn_023, avg_Cnn_024]
overall_avg_Cnn = min(avg_Cnn_values)

df = pd.DataFrame(columns=[f"R{i}" for i in range(1, 25, 1)] + ["Overall"])
df.loc['Average_RWEC'] = np.append(avg_Ltn_values, overall_avg_Ltn)
df.loc['Average_Concentration'] = np.append(avg_Cnn_values, overall_avg_Cnn)
df.loc['Min_RWEC'] = np.append(min_Ltn_values, overall_min_Ltn)
df.loc['Min_Concentration'] = np.append(min_Cnn_values, overall_min_Cnn)
df.loc['Max_RWEC'] = np.append(max_Ltn_values, overall_max_Ltn)
df.loc['Max_Concentration'] = np.append(max_Cnn_values, overall_max_Cnn)
df.to_excel('Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của cả năm từng Reach và cả Reach.xlsx')

doc.add_paragraph(f"Overall Average của Ltn: {overall_avg_Ltn}")
doc.add_paragraph(f"Overall Average của Cnn: {overall_avg_Cnn}")

doc.save("Output/Phosphate/Trung bình, Min, Max RWEC (sức tải và nồng độ) của cả năm từng Reach và cả Reach.docx")

# %%
def calculate_averages_kho(dfdry):
    ltn_average = dfdry['Ltn'].mean()
    Cnn_average = dfdry['Cnn'].mean()
    Cqc_average = dfdry['Cqc'].mean()
    return ltn_average, Cnn_average, Cqc_average

ltn_avg_dry_001, Cnn_avg_dry_001, Cqc_avg_dry_001 = calculate_averages_kho(dfkhoRWEC001)
ltn_avg_dry_002, Cnn_avg_dry_002, Cqc_avg_dry_002 = calculate_averages_kho(dfkhoRWEC002)
ltn_avg_dry_003, Cnn_avg_dry_003, Cqc_avg_dry_003 = calculate_averages_kho(dfkhoRWEC003)
ltn_avg_dry_004, Cnn_avg_dry_004, Cqc_avg_dry_004 = calculate_averages_kho(dfkhoRWEC004)
ltn_avg_dry_005, Cnn_avg_dry_005, Cqc_avg_dry_005 = calculate_averages_kho(dfkhoRWEC005)
ltn_avg_dry_006, Cnn_avg_dry_006, Cqc_avg_dry_006 = calculate_averages_kho(dfkhoRWEC006)
ltn_avg_dry_007, Cnn_avg_dry_007, Cqc_avg_dry_007 = calculate_averages_kho(dfkhoRWEC007)
ltn_avg_dry_008, Cnn_avg_dry_008, Cqc_avg_dry_008 = calculate_averages_kho(dfkhoRWEC008)
ltn_avg_dry_009, Cnn_avg_dry_009, Cqc_avg_dry_009 = calculate_averages_kho(dfkhoRWEC009)
ltn_avg_dry_010, Cnn_avg_dry_010, Cqc_avg_dry_010 = calculate_averages_kho(dfkhoRWEC010)
ltn_avg_dry_011, Cnn_avg_dry_011, Cqc_avg_dry_011 = calculate_averages_kho(dfkhoRWEC011)
ltn_avg_dry_012, Cnn_avg_dry_012, Cqc_avg_dry_012 = calculate_averages_kho(dfkhoRWEC012)
ltn_avg_dry_013, Cnn_avg_dry_013, Cqc_avg_dry_013 = calculate_averages_kho(dfkhoRWEC013)
ltn_avg_dry_014, Cnn_avg_dry_014, Cqc_avg_dry_014 = calculate_averages_kho(dfkhoRWEC014)
ltn_avg_dry_015, Cnn_avg_dry_015, Cqc_avg_dry_015 = calculate_averages_kho(dfkhoRWEC015)
ltn_avg_dry_016, Cnn_avg_dry_016, Cqc_avg_dry_016 = calculate_averages_kho(dfkhoRWEC016)
ltn_avg_dry_017, Cnn_avg_dry_017, Cqc_avg_dry_017 = calculate_averages_kho(dfkhoRWEC017)
ltn_avg_dry_018, Cnn_avg_dry_018, Cqc_avg_dry_018 = calculate_averages_kho(dfkhoRWEC018)
ltn_avg_dry_019, Cnn_avg_dry_019, Cqc_avg_dry_019 = calculate_averages_kho(dfkhoRWEC019)
ltn_avg_dry_020, Cnn_avg_dry_020, Cqc_avg_dry_020 = calculate_averages_kho(dfkhoRWEC020)
ltn_avg_dry_021, Cnn_avg_dry_021, Cqc_avg_dry_021 = calculate_averages_kho(dfkhoRWEC021)
ltn_avg_dry_022, Cnn_avg_dry_022, Cqc_avg_dry_022 = calculate_averages_kho(dfkhoRWEC022)
ltn_avg_dry_023, Cnn_avg_dry_023, Cqc_avg_dry_023 = calculate_averages_kho(dfkhoRWEC023)
ltn_avg_dry_024, Cnn_avg_dry_024, Cqc_avg_dry_024 = calculate_averages_kho(dfkhoRWEC024)
# List chứa giá trị trung bình Ltn của mùa khô
ltn_avg_dry_values = [ltn_avg_dry_001, ltn_avg_dry_002, ltn_avg_dry_003, ltn_avg_dry_004, ltn_avg_dry_005, ltn_avg_dry_006,
                      ltn_avg_dry_007, ltn_avg_dry_008, ltn_avg_dry_009, ltn_avg_dry_010, ltn_avg_dry_011, ltn_avg_dry_012,
                      ltn_avg_dry_013, ltn_avg_dry_014, ltn_avg_dry_015, ltn_avg_dry_016, ltn_avg_dry_017, ltn_avg_dry_018,
                      ltn_avg_dry_019, ltn_avg_dry_020, ltn_avg_dry_021, ltn_avg_dry_022, ltn_avg_dry_023, ltn_avg_dry_024]

# Thay thế tên Reachx thành Rx
reach_names = [f'R{i+1}' for i in range(24)]

fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 6)
# Vẽ đồ thị cột
plt.bar(reach_names, ltn_avg_dry_values, color='blue')
plt.xlabel('Reaches')
plt.ylabel('Average RWEC during dry season')
plt.title('Average RWEC across Reaches during Dry Season')
plt.show()
fig.savefig('Output/Phosphate/Average_RWEC_Dry_Season.jpg', format='jpg', dpi=1000)

# %%
def calculate_averages_uot(dfwet):
    ltn_average = dfwet['Ltn'].mean()
    Cnn_average = dfwet['Cnn'].mean()
    Cqc_average = dfwet['Cqc'].mean()
    return ltn_average, Cnn_average, Cqc_average

ltn_avg_wet_001, Cnn_avg_wet_001, Cqc_avg_wet_001 = calculate_averages_uot(dfmuaRWEC001)
ltn_avg_wet_002, Cnn_avg_wet_002, Cqc_avg_wet_002 = calculate_averages_uot(dfmuaRWEC002)
ltn_avg_wet_003, Cnn_avg_wet_003, Cqc_avg_wet_003 = calculate_averages_uot(dfmuaRWEC003)
ltn_avg_wet_004, Cnn_avg_wet_004, Cqc_avg_wet_004 = calculate_averages_uot(dfmuaRWEC004)
ltn_avg_wet_005, Cnn_avg_wet_005, Cqc_avg_wet_005 = calculate_averages_uot(dfmuaRWEC005)
ltn_avg_wet_006, Cnn_avg_wet_006, Cqc_avg_wet_006 = calculate_averages_uot(dfmuaRWEC006)
ltn_avg_wet_007, Cnn_avg_wet_007, Cqc_avg_wet_007 = calculate_averages_uot(dfmuaRWEC007)
ltn_avg_wet_008, Cnn_avg_wet_008, Cqc_avg_wet_008 = calculate_averages_uot(dfmuaRWEC008)
ltn_avg_wet_009, Cnn_avg_wet_009, Cqc_avg_wet_009 = calculate_averages_uot(dfmuaRWEC009)
ltn_avg_wet_010, Cnn_avg_wet_010, Cqc_avg_wet_010 = calculate_averages_uot(dfmuaRWEC010)
ltn_avg_wet_011, Cnn_avg_wet_011, Cqc_avg_wet_011 = calculate_averages_uot(dfmuaRWEC011)
ltn_avg_wet_012, Cnn_avg_wet_012, Cqc_avg_wet_012 = calculate_averages_uot(dfmuaRWEC012)
ltn_avg_wet_013, Cnn_avg_wet_013, Cqc_avg_wet_013 = calculate_averages_uot(dfmuaRWEC013)
ltn_avg_wet_014, Cnn_avg_wet_014, Cqc_avg_wet_014 = calculate_averages_uot(dfmuaRWEC014)
ltn_avg_wet_015, Cnn_avg_wet_015, Cqc_avg_wet_015 = calculate_averages_uot(dfmuaRWEC015)
ltn_avg_wet_016, Cnn_avg_wet_016, Cqc_avg_wet_016 = calculate_averages_uot(dfmuaRWEC016)
ltn_avg_wet_017, Cnn_avg_wet_017, Cqc_avg_wet_017 = calculate_averages_uot(dfmuaRWEC017)
ltn_avg_wet_018, Cnn_avg_wet_018, Cqc_avg_wet_018 = calculate_averages_uot(dfmuaRWEC018)
ltn_avg_wet_019, Cnn_avg_wet_019, Cqc_avg_wet_019 = calculate_averages_uot(dfmuaRWEC019)
ltn_avg_wet_020, Cnn_avg_wet_020, Cqc_avg_wet_020 = calculate_averages_uot(dfmuaRWEC020)
ltn_avg_wet_021, Cnn_avg_wet_021, Cqc_avg_wet_021 = calculate_averages_uot(dfmuaRWEC021)
ltn_avg_wet_022, Cnn_avg_wet_022, Cqc_avg_wet_022 = calculate_averages_uot(dfmuaRWEC022)
ltn_avg_wet_023, Cnn_avg_wet_023, Cqc_avg_wet_023 = calculate_averages_uot(dfmuaRWEC023)
ltn_avg_wet_024, Cnn_avg_wet_024, Cqc_avg_wet_024 = calculate_averages_uot(dfmuaRWEC024)
ltn_avg_wet_values = [ltn_avg_wet_001, ltn_avg_wet_002, ltn_avg_wet_003, ltn_avg_wet_004, ltn_avg_wet_005, ltn_avg_wet_006,
                      ltn_avg_wet_007, ltn_avg_wet_008, ltn_avg_wet_009, ltn_avg_wet_010, ltn_avg_wet_011, ltn_avg_wet_012,
                      ltn_avg_wet_013, ltn_avg_wet_014, ltn_avg_wet_015, ltn_avg_wet_016, ltn_avg_wet_017, ltn_avg_wet_018,
                      ltn_avg_wet_019, ltn_avg_wet_020, ltn_avg_wet_021, ltn_avg_wet_022, ltn_avg_wet_023, ltn_avg_wet_024]

# Vẽ đồ thị cột
fig = plt.figure()
plt.rcParams['figure.figsize'] = (12, 6)
plt.bar(reach_names, ltn_avg_wet_values, color='green')
plt.xlabel('Reaches')
plt.ylabel('Average RWEC during wet season')
plt.title('Average RWEC across Reaches during Wet Season')
plt.show()
fig.savefig('Output/Phosphate/Average_RWEC_Wet_Season.jpg', format='jpg', dpi=1000)

# %%
def calculate_averages(df):
    ltn_average = df['Ltn'].mean()
    Cnn_average = df['Cnn'].mean()
    Cqc_average = df['Cqc'].mean()
    Qs_average = df['Qs'].mean()
    return ltn_average, Cnn_average, Cqc_average, Qs_average

ltn_avg_001, Cnn_avg_001, Cqc_avg_001, Qs_avg_001 = calculate_averages(dfngay001)
ltn_avg_002, Cnn_avg_002, Cqc_avg_002, Qs_avg_002 = calculate_averages(dfngay002)
ltn_avg_003, Cnn_avg_003, Cqc_avg_003, Qs_avg_003 = calculate_averages(dfngay003)
ltn_avg_004, Cnn_avg_004, Cqc_avg_004, Qs_avg_004 = calculate_averages(dfngay004)
ltn_avg_005, Cnn_avg_005, Cqc_avg_005, Qs_avg_005 = calculate_averages(dfngay005)
ltn_avg_006, Cnn_avg_006, Cqc_avg_006, Qs_avg_006 = calculate_averages(dfngay006)
ltn_avg_007, Cnn_avg_007, Cqc_avg_007, Qs_avg_007 = calculate_averages(dfngay007)
ltn_avg_008, Cnn_avg_008, Cqc_avg_008, Qs_avg_008 = calculate_averages(dfngay008)
ltn_avg_009, Cnn_avg_009, Cqc_avg_009, Qs_avg_009 = calculate_averages(dfngay009)
ltn_avg_010, Cnn_avg_010, Cqc_avg_010, Qs_avg_010 = calculate_averages(dfngay010)
ltn_avg_011, Cnn_avg_011, Cqc_avg_011, Qs_avg_011 = calculate_averages(dfngay011)
ltn_avg_012, Cnn_avg_012, Cqc_avg_012, Qs_avg_012 = calculate_averages(dfngay012)
ltn_avg_013, Cnn_avg_013, Cqc_avg_013, Qs_avg_013 = calculate_averages(dfngay013)
ltn_avg_014, Cnn_avg_014, Cqc_avg_014, Qs_avg_014 = calculate_averages(dfngay014)
ltn_avg_015, Cnn_avg_015, Cqc_avg_015, Qs_avg_015 = calculate_averages(dfngay015)
ltn_avg_016, Cnn_avg_016, Cqc_avg_016, Qs_avg_016 = calculate_averages(dfngay016)
ltn_avg_017, Cnn_avg_017, Cqc_avg_017, Qs_avg_017 = calculate_averages(dfngay017)
ltn_avg_018, Cnn_avg_018, Cqc_avg_018, Qs_avg_018 = calculate_averages(dfngay018)
ltn_avg_019, Cnn_avg_019, Cqc_avg_019, Qs_avg_019 = calculate_averages(dfngay019)
ltn_avg_020, Cnn_avg_020, Cqc_avg_020, Qs_avg_020 = calculate_averages(dfngay020)
ltn_avg_021, Cnn_avg_021, Cqc_avg_021, Qs_avg_021 = calculate_averages(dfngay021)
ltn_avg_022, Cnn_avg_022, Cqc_avg_022, Qs_avg_022 = calculate_averages(dfngay022)
ltn_avg_023, Cnn_avg_023, Cqc_avg_023, Qs_avg_023 = calculate_averages(dfngay023)
ltn_avg_024, Cnn_avg_024, Cqc_avg_024, Qs_avg_024 = calculate_averages(dfngay024)

cnn_avg_values = [Cnn_avg_001, Cnn_avg_002, Cnn_avg_003, Cnn_avg_004, Cnn_avg_005, Cnn_avg_006,
                  Cnn_avg_007, Cnn_avg_008, Cnn_avg_009, Cnn_avg_010, Cnn_avg_011, Cnn_avg_012,
                  Cnn_avg_013, Cnn_avg_014, Cnn_avg_015, Cnn_avg_016, Cnn_avg_017, Cnn_avg_018,
                  Cnn_avg_019, Cnn_avg_020, Cnn_avg_021, Cnn_avg_022, Cnn_avg_023, Cnn_avg_024]

cqc_avg_values = [Cqc_avg_001, Cqc_avg_002, Cqc_avg_003, Cqc_avg_004, Cqc_avg_005, Cqc_avg_006,
                  Cqc_avg_007, Cqc_avg_008, Cqc_avg_009, Cqc_avg_010, Cqc_avg_011, Cqc_avg_012,
                  Cqc_avg_013, Cqc_avg_014, Cqc_avg_015, Cqc_avg_016, Cqc_avg_017, Cqc_avg_018,
                  Cqc_avg_019, Cqc_avg_020, Cqc_avg_021, Cqc_avg_022, Cqc_avg_023, Cqc_avg_024]

reach_names = [f'R{i}' for i in range(1, 25)]

fig, ax1 = plt.subplots()

# Vẽ đồ thị bar cho giá trị trung bình của Cnn trên trục tung bên trái
ax1.bar(reach_names, cnn_avg_values, color='blue', label='Phosphate Concentration')
ax1.set_xlabel('Reach')
ax1.set_ylabel('Phosphate concentration, ...', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')

# Sử dụng mô-đun twinx để tạo một trục tung khác
ax2 = ax1.twinx()

# Vẽ đồ thị line nối các giá trị trung bình của Cqc với đường đậm (không hiển thị điểm) trên trục tung bên phải
ax2.plot(np.arange(0, len(reach_names)), cqc_avg_values, linestyle='-', color='red', alpha = 0.7, linewidth=2, label='Standard')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

# Adjust y-axis limits to make them consistent
max_y_value = max(max(cnn_avg_values), max(cqc_avg_values))
ax1.set_ylim(0, max_y_value)
ax2.set_ylim(0, max_y_value)
plt.rcParams['figure.figsize'] = (12, 6)
plt.title('Annual average concentration of Phosphate at the reaches')
plt.show()
fig.savefig('Output/Phosphate/Average_Concentration_Annual.jpg', format='jpg', dpi=1000)
df = pd.DataFrame(columns = ["Reach", "Value Concentration"])
for i in range(len(cnn_avg_values)):
    value = ['R_' + str(i+1), cnn_avg_values[i]]
    df.loc[i] = value
# Save DataFrame to Excel
df.to_excel('Output/Phosphate/PhosphateAnnualConcentration.xlsx', index=False)

# %%
ltn_avg_values = [ltn_avg_001, ltn_avg_002, ltn_avg_003, ltn_avg_004, ltn_avg_005, ltn_avg_006,
                  ltn_avg_007, ltn_avg_008, ltn_avg_009, ltn_avg_010, ltn_avg_011, ltn_avg_012,
                  ltn_avg_013, ltn_avg_014, ltn_avg_015, ltn_avg_016, ltn_avg_017, ltn_avg_018,
                  ltn_avg_019, ltn_avg_020, ltn_avg_021, ltn_avg_022, ltn_avg_023, ltn_avg_024]

reach_names = [f'R{i}' for i in range(1, 25)]

fig, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (12, 6)

# Vẽ đồ thị bar cho giá trị trung bình của Cnn trên trục tung bên trái
ax1.bar(reach_names, ltn_avg_values, color='blue', label='RWEC Phosphate')
ax1.set_xlabel('Reach')
ax1.set_ylabel('Rwec Phosphate (kg/day)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')

plt.title('Annual RWEC Phosphate at the reaches')
plt.show()
fig.savefig('Output/Phosphate/Average_RWEC_Annual.jpg', format='jpg', dpi=1000)

# %%
# Danh sách giá trị trung bình của Cnn cho mỗi reach
cnn_avg_dry_values = [Cnn_avg_dry_001, Cnn_avg_dry_002, Cnn_avg_dry_003, Cnn_avg_dry_004, Cnn_avg_dry_005, Cnn_avg_dry_006,
                      Cnn_avg_dry_007, Cnn_avg_dry_008, Cnn_avg_dry_009, Cnn_avg_dry_010, Cnn_avg_dry_011, Cnn_avg_dry_012,
                      Cnn_avg_dry_013, Cnn_avg_dry_014, Cnn_avg_dry_015, Cnn_avg_dry_016, Cnn_avg_dry_017, Cnn_avg_dry_018,
                      Cnn_avg_dry_019, Cnn_avg_dry_020, Cnn_avg_dry_021, Cnn_avg_dry_022, Cnn_avg_dry_023, Cnn_avg_dry_024]

# Danh sách giá trị trung bình của Cqc cho mỗi reach
cqc_avg_dry_values = [Cqc_avg_dry_001, Cqc_avg_dry_002, Cqc_avg_dry_003, Cqc_avg_dry_004, Cqc_avg_dry_005, Cqc_avg_dry_006,
                      Cqc_avg_dry_007, Cqc_avg_dry_008, Cqc_avg_dry_009, Cqc_avg_dry_010, Cqc_avg_dry_011, Cqc_avg_dry_012,
                      Cqc_avg_dry_013, Cqc_avg_dry_014, Cqc_avg_dry_015, Cqc_avg_dry_016, Cqc_avg_dry_017, Cqc_avg_dry_018,
                      Cqc_avg_dry_019, Cqc_avg_dry_020, Cqc_avg_dry_021, Cqc_avg_dry_022, Cqc_avg_dry_023, Cqc_avg_dry_024]

reach_names = [f'R{i}' for i in range(1, 25)]

fig, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (12, 6)

# Vẽ đồ thị bar cho giá trị trung bình của Cnn trên trục tung bên trái
ax1.bar(reach_names, cnn_avg_dry_values, color='blue', label='Phosphate Concentraion')
ax1.set_xlabel('Reach')
ax1.set_ylabel('Phosphate concentration, ...', color = 'blue')
ax1.tick_params(axis='y', labelcolor='blue')
ax1.legend(loc='upper left')

# Sử dụng mô-đun twinx để tạo một trục tung khác
ax2 = ax1.twinx()

# Vẽ đồ thị line nối các giá trị trung bình của Cqc với đường đậm (không hiển thị điểm) trên trục tung bên phải
ax2.plot(np.arange(0, len(reach_names)), cqc_avg_dry_values, linestyle='-', color='red', linewidth=2, label = 'Standard')
ax2.set_ylabel('', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

# Adjust y-axis limits to make them consistent
max_y_value = max(max(cnn_avg_dry_values), max(cqc_avg_dry_values))
ax1.set_ylim(0, max_y_value)
ax2.set_ylim(0, max_y_value)

plt.title('Seasonal average concentration of Phosphate (Dry season) at the reaches')
plt.show()
df = pd.DataFrame(columns = ["Reach", "Value Concentration"])
for i in range(len(cnn_avg_dry_values)):
    value = ['R_' + str(i+1), cnn_avg_dry_values[i]]
    df.loc[i] = value
# Save DataFrame to Excel
df.to_excel('Output/Phosphate/PhosphateDryConcentration.xlsx', index=False)
fig.savefig("Output/Phosphate/Average_Concentration_Dry_Season.jpg", format='jpg', dpi=1000)
print("Excel file saved successfully.")
# Out:
# Excel file saved successfully.

# %%
# Danh sách giá trị trung bình của Cnn cho mỗi reach
cnn_avg_wet_values = [Cnn_avg_wet_001, Cnn_avg_wet_002, Cnn_avg_wet_003, Cnn_avg_wet_004, Cnn_avg_wet_005, Cnn_avg_wet_006,
                      Cnn_avg_wet_007, Cnn_avg_wet_008, Cnn_avg_wet_009, Cnn_avg_wet_010, Cnn_avg_wet_011, Cnn_avg_wet_012,
                      Cnn_avg_wet_013, Cnn_avg_wet_014, Cnn_avg_wet_015, Cnn_avg_wet_016, Cnn_avg_wet_017, Cnn_avg_wet_018,
                      Cnn_avg_wet_019, Cnn_avg_wet_020, Cnn_avg_wet_021, Cnn_avg_wet_022, Cnn_avg_wet_023, Cnn_avg_wet_024]

# Danh sách giá trị trung bình của Cqc cho mỗi reach
cqc_avg_wet_values = [Cqc_avg_wet_001, Cqc_avg_wet_002, Cqc_avg_wet_003, Cqc_avg_wet_004, Cqc_avg_wet_005, Cqc_avg_wet_006,
                      Cqc_avg_wet_007, Cqc_avg_wet_008, Cqc_avg_wet_009, Cqc_avg_wet_010, Cqc_avg_wet_011, Cqc_avg_wet_012,
                      Cqc_avg_wet_013, Cqc_avg_wet_014, Cqc_avg_wet_015, Cqc_avg_wet_016, Cqc_avg_wet_017, Cqc_avg_wet_018,
                      Cqc_avg_wet_019, Cqc_avg_wet_020, Cqc_avg_wet_021, Cqc_avg_wet_022, Cqc_avg_wet_023, Cqc_avg_wet_024]

reach_names = [f'R{i}' for i in range(1, 25)]

fig, ax1 = plt.subplots()
plt.rcParams['figure.figsize'] = (12, 6)

# Vẽ đồ thị bar cho giá trị trung bình của Cnn trên trục tung bên trái
ax1.bar(reach_names, cnn_avg_wet_values, color='green', label='Phosphate Concentraion')
ax1.set_xlabel('Reaches')
ax1.set_ylabel('Phosphate Concentraion, ...', color='green')
ax1.tick_params(axis='y', labelcolor='green')
ax1.legend(loc='upper left')

# Sử dụng mô-đun twinx để tạo một trục tung khác
ax2 = ax1.twinx()

# Vẽ đồ thị line nối các giá trị trung bình của Cqc với đường đậm (không hiển thị điểm) trên trục tung bên phải
ax2.plot(reach_names, cqc_avg_wet_values, linestyle='-', color='red', linewidth=2, label='Standard')
ax2.set_ylabel('', color='red')
ax2.tick_params(axis='y', labelcolor='red')
ax2.legend(loc='upper right')

# Adjust y-axis limits to make them consistent
max_y_value = max(max(cnn_avg_wet_values), max(cqc_avg_wet_values))
ax1.set_ylim(0, max_y_value)
ax2.set_ylim(0, max_y_value)

plt.title('Seasonal average concentration of Phosphate (Wet season) at the reaches')
plt.show()
df = pd.DataFrame(columns = ["Reach", "Value Concentration"])
for i in range(len(cnn_avg_wet_values)):
    value = ['R_' + str(i+1), cnn_avg_wet_values[i]]
    df.loc[i] = value
# Save DataFrame to Excel
df.to_excel('Output/Phosphate/PhosphateWetConcentration.xlsx', index=False)
fig.savefig("Output/Phosphate/Average_Concentration_Wet_Season.jpg", format='jpg', dpi=1000)
print("Excel file saved successfully.")
# Out:
# Excel file saved successfully.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dữ liệu mẫu
cnn_avg_values = [Cnn_avg_001, Cnn_avg_002, Cnn_avg_003, Cnn_avg_004, Cnn_avg_005, Cnn_avg_006,
                  Cnn_avg_007, Cnn_avg_008, Cnn_avg_009, Cnn_avg_010, Cnn_avg_011, Cnn_avg_012,
                  Cnn_avg_013, Cnn_avg_014, Cnn_avg_015, Cnn_avg_016, Cnn_avg_017, Cnn_avg_018,
                  Cnn_avg_019, Cnn_avg_020, Cnn_avg_021, Cnn_avg_022, Cnn_avg_023, Cnn_avg_024]

ltn_avg_values = [ltn_avg_001, ltn_avg_002, ltn_avg_003, ltn_avg_004, ltn_avg_005, ltn_avg_006,
                  ltn_avg_007, ltn_avg_008, ltn_avg_009, ltn_avg_010, ltn_avg_011, ltn_avg_012,
                  ltn_avg_013, ltn_avg_014, ltn_avg_015, ltn_avg_016, ltn_avg_017, ltn_avg_018,
                  ltn_avg_019, ltn_avg_020, ltn_avg_021, ltn_avg_022, ltn_avg_023, ltn_avg_024]

reach_names = [f'R{i}' for i in range(1, 25)]
bar_positions = np.arange(len(reach_names))

# Dữ liệu cho đường thẳng (Standard)
cqc_avg_values = [Cqc_avg_001, Cqc_avg_002, Cqc_avg_003, Cqc_avg_004, Cqc_avg_005, Cqc_avg_006,
                  Cqc_avg_007, Cqc_avg_008, Cqc_avg_009, Cqc_avg_010, Cqc_avg_011, Cqc_avg_012,
                  Cqc_avg_013, Cqc_avg_014, Cqc_avg_015, Cqc_avg_016, Cqc_avg_017, Cqc_avg_018,
                  Cqc_avg_019, Cqc_avg_020, Cqc_avg_021, Cqc_avg_022, Cqc_avg_023, Cqc_avg_024]

fig, ax1 = plt.subplots(figsize=(12, 6))

# Vẽ đồ thị cột A trên trục tung bên trái
bar_width = 0.4
ax1.bar(bar_positions, cnn_avg_values, width=bar_width, color='blue', alpha=0.7, label='Phosphate Concentration (mg/l)')

# Thiết lập các nhãn trục tung cho giá trị A
ax1.set_xticks(bar_positions)
ax1.set_xticklabels(reach_names)
ax1.set_ylabel('Phosphate Concentration', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Tạo một trục tung mới cho giá trị B
ax2 = ax1.twinx()

# Vẽ đồ thị cột B trên trục tung bên phải
ax2.bar(bar_positions + bar_width, ltn_avg_values, width=bar_width, color='green', alpha=0.7, label='RWEC Phosphate (kg/day)')

# Thiết lập các nhãn trục tung cho giá trị B
ax2.set_xticks(bar_positions + bar_width / 2)
ax2.set_xticklabels(reach_names)
ax2.set_ylabel('RWEC Phosphate', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Đảm bảo số 0 ở trục tung bên trái và phải nằm ngang với nhau
min_y_value_a, max_y_value_a = ax1.get_ylim()
min_y_value_b, max_y_value_b = ax2.get_ylim()
max_ax1 = max(abs(min_y_value_a), abs(max_y_value_a))
max_ax2 = max(abs(min_y_value_b), abs(max_y_value_b))

# ax2.set_ylim(new_min_y_value_b, new_max_y_value_b)
ax1.set_ylim(-max_ax1, max_ax1)
ax2.set_ylim(-max_ax2, max_ax2)

# Tạo ax3 và vẽ đường chuẩn
ax3 = ax1.twinx()
ax3.plot(bar_positions, cqc_avg_values, linestyle='-', color='red', linewidth=2, label='Standard')

# Đảm bảo y-limits của ax3 trùng khớp với ax1
ax3.set_ylim(ax1.get_ylim())

# Ẩn trục tung của ax3
ax3.spines['right'].set_visible(False)
ax3.yaxis.set_ticks_position('none')
ax3.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True, pad=10)
ax3.set_yticklabels([])

# Đánh dấu giá trị chuẩn
ax3.annotate("4.0 mg/l", (bar_positions[12], 4.0), textcoords="offset points", xytext=(0, 5), ha='center', color='red', fontsize=14)

# Hiển thị legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')
ax3.legend(loc='upper left', bbox_to_anchor=(0, 0.94))

# Thiết lập tiêu đề
plt.title('Relationship between RWEC and pollutant concentration (Phosphate)')

plt.show()
fig.savefig("Output/Phosphate/Relationship_RWEC_Concentration.jpg", format='jpg', dpi=1000)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dữ liệu mẫu
qs_avg_values = [Qs_avg_001, Qs_avg_002, Qs_avg_003, Qs_avg_004, Qs_avg_005, Qs_avg_006,
                  Qs_avg_007, Qs_avg_008, Qs_avg_009, Qs_avg_010, Qs_avg_011, Qs_avg_012,
                  Qs_avg_013, Qs_avg_014, Qs_avg_015, Qs_avg_016, Qs_avg_017, Qs_avg_018,
                  Qs_avg_019, Qs_avg_020, Qs_avg_021, Qs_avg_022, Qs_avg_023, Qs_avg_024]

ltn_avg_values = [ltn_avg_001, ltn_avg_002, ltn_avg_003, ltn_avg_004, ltn_avg_005, ltn_avg_006,
                  ltn_avg_007, ltn_avg_008, ltn_avg_009, ltn_avg_010, ltn_avg_011, ltn_avg_012,
                  ltn_avg_013, ltn_avg_014, ltn_avg_015, ltn_avg_016, ltn_avg_017, ltn_avg_018,
                  ltn_avg_019, ltn_avg_020, ltn_avg_021, ltn_avg_022, ltn_avg_023, ltn_avg_024]

reach_names = [f'R{i}' for i in range(1, 25)]
bar_positions = np.arange(len(reach_names))

# Dữ liệu cho đường thẳng (Standard)
cqc_avg_values = [Cqc_avg_001, Cqc_avg_002, Cqc_avg_003, Cqc_avg_004, Cqc_avg_005, Cqc_avg_006,
                  Cqc_avg_007, Cqc_avg_008, Cqc_avg_009, Cqc_avg_010, Cqc_avg_011, Cqc_avg_012,
                  Cqc_avg_013, Cqc_avg_014, Cqc_avg_015, Cqc_avg_016, Cqc_avg_017, Cqc_avg_018,
                  Cqc_avg_019, Cqc_avg_020, Cqc_avg_021, Cqc_avg_022, Cqc_avg_023, Cqc_avg_024]

fig, ax1 = plt.subplots(figsize=(12, 6))

# Vẽ đồ thị cột A trên trục tung bên trái
bar_width = 0.4
ax1.bar(bar_positions, qs_avg_values, width=bar_width, color='blue', alpha=0.7, label='River Discharge $(m^3/s)$')

# Thiết lập các nhãn trục tung cho giá trị A
ax1.set_xticks(bar_positions)
ax1.set_xticklabels(reach_names)
ax1.set_ylabel('River Discharge', color = 'blue')
ax1.tick_params(axis='y', labelcolor='blue')
# Tạo một trục tung mới cho giá trị B
ax2 = ax1.twinx()

# Vẽ đồ thị cột B trên trục tung bên phải
ax2.bar(bar_positions + bar_width, ltn_avg_values, width=bar_width, color='green', alpha=0.7, label='RWEC Phosphate $(kg/day)$')

# Thiết lập các nhãn trục tung cho giá trị B
ax2.set_xticks(bar_positions + bar_width / 2)
ax2.set_xticklabels(reach_names)
ax2.set_ylabel('RWEC Phosphate', color = 'green')
ax2.tick_params(axis='y', labelcolor='green')

# Đảm bảo số 0 ở trục tung bên trái và phải nằm ngang với nhau
min_y_value_a, max_y_value_a = ax1.get_ylim()
min_y_value_b, max_y_value_b = ax2.get_ylim()
max_ax1 = max(abs(min_y_value_a), abs(max_y_value_a))
max_ax2 = max(abs(min_y_value_b), abs(max_y_value_b))

# ax2.set_ylim(new_min_y_value_b, new_max_y_value_b)
ax1.set_ylim(-max_ax1, max_ax1)
ax2.set_ylim(-max_ax2, max_ax2)

# Hiển thị legend
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

# Thiết lập tiêu đề
plt.title('Relationship between RWEC$_{Phosphate}$ and River Discharge')

plt.show()

fig.savefig("Output/Phosphate/Relationship_RWEC_RiverDischarge.jpg", format='jpg', dpi=1000)

# %%
# Create a figure with subplots
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the combined set of data (Cnn kho và Cnn uot)
bar_width = 0.35
bar_positions1 = np.arange(len(reach_names))

ax1.bar(bar_positions1, ltn_avg_dry_values, width=bar_width, color='blue', alpha=0.7, label='Average RWEC Dry Season')
ax1.bar(bar_positions1 + bar_width, ltn_avg_wet_values, width=bar_width, color='green', alpha=0.7, label='Average RWEC Wet Season')

ax1.set_xlabel('Reach')
ax1.set_ylabel('Rwec Phosphate (kg/day)')
ax1.tick_params(axis='y')

ax1.legend(loc='upper left')

plt.title('Seasonal RWEC of Phosphate (Wet and Dry Season) at the reaches')
plt.show()
fig.savefig("Output/Phosphate/Seasonal_RWEC.jpg", format="jpg", dpi=1000)

# %%
# Create a figure with subplots
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the combined set of data (Cnn kho và Cnn uot)
bar_width = 0.35
bar_positions1 = np.arange(len(reach_names))

ax1.bar(bar_positions1, ltn_avg_dry_values, width=bar_width, color='blue', alpha=0.7, label='Average Concentration Dry Season')
ax1.bar(bar_positions1 + bar_width, ltn_avg_wet_values, width=bar_width, color='green', alpha=0.7, label='Average Concentration Wet Season')

ax1.set_xlabel('Reach')
ax1.set_ylabel('Concentration Phosphate (mg/l)')
ax1.tick_params(axis='y')

ax1.legend(loc='upper left')

plt.title('Seasonal Concentration of Phosphate (Wet and Dry Season) at the reaches')
plt.show()
fig.savefig("Output/Phosphate/Seasonal_Concentration.jpg", format="jpg", dpi=1000)
