# %%
import pandas as pd
import numpy as np
import rasterio
from geopy.distance import geodesic
import matplotlib.pyplot as plt
import os
import time  # for sleep in case of PermissionError

BASE_PATH = "G:/Big_Data_Preprocessing/Water/Cross_Section"

def calculate_distances(path):
    return np.cumsum(
        [0] + [geodesic(path[i], path[i + 1]).meters for i in range(len(path) - 1)]
    )

def generate_path(start, end, num_points):
    latitudes = np.linspace(start[0], end[0], num_points)
    longitudes = np.linspace(start[1], end[1], num_points)
    path = list(zip(longitudes, latitudes))
    return path

data = pd.read_excel(f'../Data/Excel/MCwill_final.xlsx', index_col=0)
i = 0
os.makedirs('../Output_MCWillFinal/Image', exist_ok=True)
os.makedirs('../Output_MCWillFinal/Excel', exist_ok=True)

while i < int(data.shape[0]):
    print(data.iloc[i])
    Long_First_Point = float(data.iloc[i]["Long First Point"])
    Lat_First_Point = float(data.iloc[i]["Lat First Point"])
    Region_First_Point = data.iloc[i]["Region First Point"]
    Long_Second_Point = float(data.iloc[i]["Long Second Point"])
    Lat_Second_Point = float(data.iloc[i]["Lat Second Point"])
    Region_Second_Point = data.iloc[i]["Region Second Point"]
    
    First_Point = (Lat_First_Point, Long_First_Point)
    Second_Point = (Lat_Second_Point, Long_Second_Point)
    Distance = geodesic(First_Point, Second_Point).meters
    
    # Generate path
    path = generate_path(First_Point, Second_Point, int(Distance / 3))
    
    # Read raster
    srtm_file = f'../Data/GeoTIFF/{Region_First_Point}.tif'
    elevations = []
    with rasterio.open(srtm_file) as dataset:
        for attempt in range(3):
            try:
                dataset_read = dataset.read(1)
                break
            except:
                print("Error")
        for lon, lat in path:
            row, col = dataset.index(lon, lat)
            elevations.append(dataset_read[row, col])
    
    distances_segments = [
        geodesic((path[j][1], path[j][0]), (path[j+1][1], path[j+1][0])).meters
        for j in range(len(path) - 1)
    ]
    total_distance = sum(distances_segments)
    
    fig = plt.figure(figsize=(10, 6))
    try:
        plt.plot(np.cumsum([0] + distances_segments), elevations, marker='o')
    except:
        # If there's an error plotting, just skip this iteration
        i += 1
        continue
    
    plt.xlabel('Distance (meters)')
    plt.ylabel('Elevation (meters)')
    plt.title('Elevation Profile')
    plt.grid(True)
    plt.show()
    
    name = i
    # ------------------------------
    # Save figure with retry logic
    # ------------------------------
    for attempt in range(3):
        try:
            fig.savefig(f'../Output_MCWillFinal/Image/ID_{name+1}.png')
            break
        except PermissionError:
            print("PermissionError while saving figure. Retrying in 1 second...")
            time.sleep(1)
    
    # Create DataFrame for Excel
    df_out = pd.DataFrame(columns=["Depth", "Distance"])
    csum_distances = np.cumsum([0] + distances_segments)
    for j in range(len(elevations)):
        elevation = elevations[j]
        distance = csum_distances[j]
        df_out.loc[j] = [elevation, distance]
    
    # ------------------------------
    # Save Excel with retry logic
    # ------------------------------
    for attempt in range(3):
        try:
            df_out.to_excel(f'../Output_MCWillFinal/Excel/ID_{name+1}.xlsx')
            break
        except PermissionError:
            print("PermissionError while saving Excel. Retrying in 1 second...")
            time.sleep(1)
    
    i += 1
# Out:
# Long First Point                    -122.939309
# Lat First Point                       43.970423
# Region First Point     USGS_13_n44w123_20231102
# Long Second Point                   -122.907046
# Lat Second Point                       44.00359
# Region Second Point    USGS_13_n45w123_20220426
# Name: 0, dtype: object
# Long First Point                     -122.91892
# Lat First Point                       44.014692
# Region First Point     USGS_13_n45w123_20220426
# Long Second Point                   -122.945606
# Lat Second Point                      44.002599
# Region Second Point    USGS_13_n45w123_20220426
# Name: 1, dtype: object
# Long First Point                     -122.94732
# Lat First Point                       44.008595
# Region First Point     USGS_13_n45w123_20220426
# Long Second Point                   -122.923584
# Lat Second Point                      44.022211
# Region Second Point    USGS_13_n45w123_20220426
# Name: 2, dtype: object
# Long First Point                    -122.956647
# Lat First Point                       44.016876
# Region First Point     USGS_13_n45w123_20220426
# Long Second Point                   -122.941514
# Lat Second Point                      44.037625
# Region Second Point    USGS_13_n45w123_20220426
# Name: 3, dtype: object
# Long First Point                    -122.983202
# Lat First Point                       44.023729
# Region First Point     USGS_13_n45w123_20220426
# Long Second Point                    -122.97692
# Lat Second Point                      44.029439
# Region Second Point    USGS_13_n45w123_20220426
# Name: 4, dtype: object
# Long First Point                     -123.00464
# Lat First Point                       44.023457
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                    -123.00614
# Lat Second Point                       44.02687
# Region Second Point    USGS_13_n45w124_20220426
# Name: 5, dtype: object
# Long First Point                    -123.019503
# Lat First Point                       44.012878
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.013164
# Lat Second Point                      44.029668
# Region Second Point    USGS_13_n45w124_20220426
# Name: 6, dtype: object
# Long First Point                    -123.035074
# Lat First Point                       44.036625
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.023653
# Lat Second Point                      44.042564
# Region Second Point    USGS_13_n45w124_20220426
# Name: 7, dtype: object
# Long First Point                    -123.057346
# Lat First Point                       44.044506
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.056204
# Lat Second Point                      44.047761
# Region Second Point    USGS_13_n45w124_20220426
# Name: 8, dtype: object
# Long First Point                    -123.078076
# Lat First Point                       44.050217
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.077904
# Lat Second Point                      44.053301
# Region Second Point    USGS_13_n45w124_20220426
# Name: 9, dtype: object
# Long First Point                    -123.106559
# Lat First Point                       44.059053
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.100729
# Lat Second Point                       44.07333
# Region Second Point    USGS_13_n45w124_20220426
# Name: 10, dtype: object
# Long First Point                      -123.1206
# Lat First Point                       44.089275
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                    -123.11627
# Lat Second Point                      44.088513
# Region Second Point    USGS_13_n45w124_20220426
# Name: 11, dtype: object
# Long First Point                    -123.111563
# Lat First Point                       44.121124
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.103473
# Lat Second Point                       44.12618
# Region Second Point    USGS_13_n45w124_20220426
# Name: 12, dtype: object
# Long First Point                    -123.120005
# Lat First Point                       44.132266
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                    -123.11803
# Lat Second Point                      44.133765
# Region Second Point    USGS_13_n45w124_20220426
# Name: 13, dtype: object
# Long First Point                    -123.121362
# Lat First Point                       44.143153
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.116841
# Lat Second Point                      44.141678
# Region Second Point    USGS_13_n45w124_20220426
# Name: 14, dtype: object
# Long First Point                    -123.132225
# Lat First Point                       44.155011
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.127109
# Lat Second Point                      44.155891
# Region Second Point    USGS_13_n45w124_20220426
# Name: 15, dtype: object
# Long First Point                    -123.134987
# Lat First Point                         44.1751
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.125814
# Lat Second Point                      44.180026
# Region Second Point    USGS_13_n45w124_20220426
# Name: 16, dtype: object
# Long First Point                    -123.146622
# Lat First Point                       44.185558
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                    -123.14341
# Lat Second Point                      44.186308
# Region Second Point    USGS_13_n45w124_20220426
# Name: 17, dtype: object
# Long First Point                    -123.155117
# Lat First Point                       44.196979
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.154724
# Lat Second Point                      44.199264
# Region Second Point    USGS_13_n45w124_20220426
# Name: 18, dtype: object
# Long First Point                    -123.167645
# Lat First Point                       44.203404
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.160506
# Lat Second Point                      44.202226
# Region Second Point    USGS_13_n45w124_20220426
# Name: 19, dtype: object
# Long First Point                     -123.16172
# Lat First Point                       44.219215
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.153625
# Lat Second Point                      44.215677
# Region Second Point    USGS_13_n45w124_20220426
# Name: 20, dtype: object
# Long First Point                    -123.152847
# Lat First Point                        44.22474
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.149973
# Lat Second Point                      44.223976
# Region Second Point    USGS_13_n45w124_20220426
# Name: 21, dtype: object
# Long First Point                    -123.167526
# Lat First Point                       44.236704
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.158365
# Lat Second Point                      44.242534
# Region Second Point    USGS_13_n45w124_20220426
# Name: 22, dtype: object
# Long First Point                    -123.179709
# Lat First Point                        44.23906
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.159293
# Lat Second Point                      44.253194
# Region Second Point    USGS_13_n45w124_20220426
# Name: 23, dtype: object
# Long First Point                    -123.181565
# Lat First Point                       44.257227
# Region First Point     USGS_13_n45w124_20220426
# Long Second Point                   -123.158865
# Lat Second Point                      44.259048
# Region Second Point    USGS_13_n45w124_20220426
# Name: 24, dtype: object
